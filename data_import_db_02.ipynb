# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Aug 12 11:49:08 2019
@author: wangxinyi
"""
import pymysql
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os
conn= pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='root123',charset='utf8',db='car_evaluation')
engine=create_engine("mysql+pymysql://root:root123@127.0.0.1:3306/car_evaluation?charset=utf8", max_overflow=5)

all_df = pd.read_sql_query('''select * from tianchi_01_train''',conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1399             else:
# -> 1400                 cur.execute(*args)
#    1401             return cur
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
# ...

# %%
''' 
df=pd.read_csv("hy_round1_train_20200102/1.csv")
df.columns=['id','x','y','v','d','t','ty']
df.to_sql('tianchi_01_train', con=engine, if_exists='append',index =False)
'''
# Out:
# ' \ndf=pd.read_csv("hy_round1_train_20200102/1.csv")\ndf.columns=[\'id\',\'x\',\'y\',\'v\',\'d\',\'t\',\'ty\']\ndf.to_sql(\'tianchi_01_train\', con=engine, if_exists=\'append\',index =False)\n'

# %%
filelist=os.listdir("hy_round1_train_20200102/")
for file in filelist:
    file="hy_round1_train_20200102/"+file
    df=pd.read_csv(file)
    df.columns=['id','x','y','v','d','t','ty']
    df.to_sql('tianchi_01_train', con=engine, if_exists='append',index =False)
    print(file)
# Out:
# hy_round1_train_20200102/0.csv
# hy_round1_train_20200102/1.csv
# hy_round1_train_20200102/10.csv
# hy_round1_train_20200102/100.csv
# hy_round1_train_20200102/1000.csv
# hy_round1_train_20200102/1001.csv
# hy_round1_train_20200102/1002.csv
# hy_round1_train_20200102/1003.csv
# hy_round1_train_20200102/1004.csv
# hy_round1_train_20200102/1005.csv
# hy_round1_train_20200102/1006.csv
# hy_round1_train_20200102/1007.csv
# hy_round1_train_20200102/1008.csv
# hy_round1_train_20200102/1009.csv
# hy_round1_train_20200102/101.csv
# hy_round1_train_20200102/1010.csv
# hy_round1_train_20200102/1011.csv
# hy_round1_train_20200102/1012.csv
# hy_round1_train_20200102/1013.csv
# hy_round1_train_20200102/1014.csv
# hy_round1_train_20200102/1015.csv
# hy_round1_train_20200102/1016.csv
# hy_round1_train_20200102/1017.csv
# hy_round1_train_20200102/1018.csv
# hy_round1_train_20200102/1019.csv
# hy_round1_train_20200102/102.csv
# hy_round1_train_20200102/1020.csv
# hy_round1_train_20200102/1021.csv
# ...

# %%
filelist=os.listdir("hy_round1_testA_20200102/")
for file in filelist:
    file="hy_round1_testA_20200102/"+file
    df=pd.read_csv(file)
    df.columns=['id','x','y','v','d','t']
    df.to_sql('tianchi_01_test', con=engine, if_exists='append',index =False)
    print(file)
# Out:
# hy_round1_testA_20200102/7000.csv
# hy_round1_testA_20200102/7001.csv
# hy_round1_testA_20200102/7002.csv
# hy_round1_testA_20200102/7003.csv
# hy_round1_testA_20200102/7004.csv
# hy_round1_testA_20200102/7005.csv
# hy_round1_testA_20200102/7006.csv
# hy_round1_testA_20200102/7007.csv
# hy_round1_testA_20200102/7008.csv
# hy_round1_testA_20200102/7009.csv
# hy_round1_testA_20200102/7010.csv
# hy_round1_testA_20200102/7011.csv
# hy_round1_testA_20200102/7012.csv
# hy_round1_testA_20200102/7013.csv
# hy_round1_testA_20200102/7014.csv
# hy_round1_testA_20200102/7015.csv
# hy_round1_testA_20200102/7016.csv
# hy_round1_testA_20200102/7017.csv
# hy_round1_testA_20200102/7018.csv
# hy_round1_testA_20200102/7019.csv
# hy_round1_testA_20200102/7020.csv
# hy_round1_testA_20200102/7021.csv
# hy_round1_testA_20200102/7022.csv
# hy_round1_testA_20200102/7023.csv
# hy_round1_testA_20200102/7024.csv
# hy_round1_testA_20200102/7025.csv
# hy_round1_testA_20200102/7026.csv
# ...
